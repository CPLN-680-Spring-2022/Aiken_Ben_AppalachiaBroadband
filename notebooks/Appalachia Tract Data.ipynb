# %% [markdown]
# # Appalachia Tract Data

# %% [markdown]
# This notebook downloads relevant 2020 acs data for all Appalachia census tracts. <br>
# The census tract shapefiles are merged. <br>
# Finally, it is saved as: app_tract.shp

# %%
import cenpy
import pandas as pd
import geopandas as gpd

# %%
acs = cenpy.remote.APIConnection("ACSDT5Y2020")

# %%
#define variables
variables = [
    "NAME",
    "STATE",
    "COUNTY",
    "TRACT",
    "B01003_001E", #total pop
    "B28002_001E", #Total Households for internet
    "B28002_002E", #Total with Internet
    "B28002_003E", #Dial-up with no other
    "B28002_004E", #Broadband of any type
    "B28002_005E", #Cellular data plan
    "B28002_006E", #Cellular data no other type
    "B28002_007E", #Broadband such as cable, fiber optic, or DSL
    "B28002_008E", #Broadband such as cable, fiber optic, or DSL no other type
    "B28002_009E", #Satelitte
    "B28002_010E", #Satelitte no other type
    "B28002_011E", #Other service, no other type
    "B28002_012E", #Internet without a subscription
    "B28002_013E", #No internet access
    "B28003_001E", #Total Households for computer
    "B28003_002E", #Has a computer
    "B28003_003E", #Has a computer with dial-up
    "B28003_004E", #Has a computer with broadband
    "B28003_005E", #Has a computer without internet
    "B28003_006E", #Does not have a computer
    "B28004_001E", #Total Households for income and internet
    "B28004_002E", #Less than 10k
    "B28004_003E", #Less than 10k, with dial-up
    "B28004_004E", #Less than 10k, with broadband
    "B28004_005E", #Less than 10k, without internet subscription
    "B28004_006E", #10k to 20k
    "B28004_007E", #10k to 20k, with dial up
    "B28004_008E", #10k to 20k, with broadband
    "B28004_009E", #10k to 20k, without internet subscription
    "B28004_010E", #20k to 35k
    "B28004_011E", #20k to 35k, with dial up
    "B28004_012E", #20k to 35k, with broadband
    "B28004_013E", #20k to 35k, without internet subscription
    "B28004_014E", #35k to 50k
    "B28004_015E", #35k to 50k, with dial up
    "B28004_016E", #35k to 50k, with broadband
    "B28004_017E", #35k to 50k, without internet subscription
    "B28004_018E", #50k to 75k
    "B28004_019E", #50k to 75k, with dial up
    "B28004_020E", #50k to 75k, with broadband
    "B28004_021E", #50k to 75k, without internet subscription
    "B28004_022E", #75k+
    "B28004_023E", #75k+, with dial up
    "B28004_024E", #75k+, with broadband
    "B28004_025E", #75k+, without internet subscription
    "B28005_001E", #Total Households for age groups
    "B28005_002E", #Under 18
    "B28005_003E", #Under 18, has a computer
    "B28005_004E", #Under 18, has a computer, with dial up
    "B28005_005E", #Under 18, has a computer, with broadband
    "B28005_006E", #Under 18, has a computer, without internet subscription
    "B28005_007E", #Under 18, no computer
    "B28005_008E", #18 to 64
    "B28005_009E", #18 to 64, has a computer
    "B28005_010E", #18 to 64, has a computer, with dial up
    "B28005_011E", #18 to 64, has a computer, with broadband
    "B28005_012E", #18 to 64, has a computer, without internet subscription
    "B28005_013E", #18 to 64, no computer
    "B28005_014E", #65+
    "B28005_015E", #65+, has a computer
    "B28005_016E", #65+, has a computer, with dial up
    "B28005_017E", #65+, has a computer, with broadband
    "B28005_018E", #65+, has a computer, without internet subscription
    "B28005_019E", #65+, no computer
    "B28006_001E", #Total Households for education
    "B28006_002E", #Less than HS grad
    "B28006_003E", #Less than HS grad, has a computer
    "B28006_004E", #Less than HS grad, has a computer, with dial up
    "B28006_005E", #Less than HS grad, has a computer, with broadband
    "B28006_006E", #Less than HS grad, has a computer, without internet subscription
    "B28006_007E", #Less than HS grad, no computer
    "B28006_008E", #HS grad but not college
    "B28006_009E", #HS grad but not college, has a computer
    "B28006_010E", #HS grad but not college, has a computer, with dial up
    "B28006_011E", #HS grad but not college, has a computer, with broadband
    "B28006_012E", #HS grad but not college, has a computer, without internet subscription
    "B28006_013E", #HS grad but not college, no computer
    "B28006_014E", #Bachelor's or higher
    "B28006_015E", #Bachelor's or higher, has a computer
    "B28006_016E", #Bachelor's or higher, has a computer, with dial up
    "B28006_017E", #Bachelor's or higher, has a computer, with broadband
    "B28006_018E", #Bachelor's or higher, has a computer, without internet subscription
    "B28006_019E", #Bachelor's or higher, no computer
    "B28007_001E", #Total Housholds for labor force
    "B28007_002E", #Civilian labor force
    "B28007_003E", #Civilian labor force, employed
    "B28007_004E", #Civilian labor force, employed, has a computer
    "B28007_005E", #Civilian labor force, employed, has a computer, with dial up
    "B28007_006E", #Civilian labor force, employed, has a computer, with broadband
    "B28007_007E", #Civilian labor force, employed, has a computer, without internet subscription
    "B28007_008E", #Civilian labor force, employed, no computer
    "B28007_009E", #Civilian labor force, unemployed
    "B28007_010E", #Civilian labor force, unemployed, has a computer
    "B28007_011E", #Civilian labor force, unemployed, has a computer, with dial up
    "B28007_012E", #Civilian labor force, unemployed, has a computer, with broadband
    "B28007_013E", #Civilian labor force, unemployed, has a computer, without internet subscription
    "B28007_014E", #Civilian labor force, unemployed, no computer
    "B28007_015E", #Not in labor force
    "B28007_016E", #Not in labor force, has a computer
    "B28007_017E", #Not in labor force, has a computer, with dial up
    "B28007_018E", #Not in labor force, has a computer, with broadband
    "B28007_019E", #Not in labor force, has a computer, without internet subscription
    "B28007_020E", #Not in labor force, no computer
]

# %%
#Alabama Appalachia Counties
AL_state_code = "01"
AL_app_counties = [
    "7", #Bibb
    "9", #Blount
    "15", #Calhoun
    "17", #Chambers
    "19", #Cherokee
    "21", #Chilton
    "27", #Clay
    "29", #Cleburne
    "33", #Colbert
    "37", #Coosa
    "43", #Cullman
    "49", #De Kalb
    "51", #Elmore
    "55", #Etowah
    "57", #Fayette
    "59", #Franklin
    "65", #Hale
    "71", #Jackson
    "73", #Jefferson
    "75", #Lamar
    "77", #Lauderdale
    "79", #Lawrence
    "83", #Limestone
    "87", #Macon
    "89", #Madison
    "93", #Marion
    "95", #Marshall    
    "103", #Morgan
    "107", #Pickens
    "111", #Randolph
    "115", #St. Clair
    "117", #Shelby
    "121", #Talladega
    "123", #Tallapoosa
    "125", #Tuscaloosa
    "127", #Walker
    "133", #Winston
]

# %%
#Alabama Query
AL_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": AL_state_code},
)

# %%
#Georgia Appalachia Counties
GA_state_code = "13"
GA_app_counties = [
    "11", #Banks
    "13", #Barrow
    "15", #Bartow
    "45", #Carroll
    "47", #Catoosa
    "55", #Chattooga
    "57", #Cherokee
    "83", #Dade
    "85", #Dawson
    "97", #Douglas
    "105", #Elbert
    "111", #Fannin
    "115", #Floyd
    "117", #Forsyth
    "119", #Franklin
    "123", #Gilmer
    "129", #Gordon
    "135", #Gwinnett
    "137", #Habersham
    "139", #Hall
    "143", #Haralson
    "147", #Hart
    "149", #Heard
    "157", #Jackson
    "187", #Lumpkin
    "195", #Madison
    "213", #Murray
    "223", #Paulding
    "227", #Pickens
    "233", #Polk
    "241", #Rabun
    "257", #Stephens
    "281", #Towns
    "291", #Union
    "295", #Walker
    "311", #White
    "313", #Whitfield
]

# %%
#Georgia Query
GA_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": GA_state_code},
)

# %%
#Kentucky Appalachia Counties
KY_state_code = "21"
KY_app_counties = [
    "1", #Adair
    "11", #Bath
    "13", #Bell
    "19", #Boyd
    "25", #Breathitt
    "43", #Carter
    "43", #Casey
    "49", #Clark
    "51", #Clay
    "53", #Clinton
    "57", #Cumberland
    "61", #Edmonson
    "63", #Elliott
    "65", #Estill
    "69", #Fleming
    "71", #Floyd
    "79", #Garrard
    "87", #Green
    "89", #Greenup
    "95", #Harlan
    "99", #Hart
    "109", #Jackson
    "115", #Johnson
    "119", #Knott
    "121", #Knox
    "125", #Laurel
    "127", #Lawrence
    "129", #Lee
    "131", #Leslie
    "133", #Letcher
    "135", #Lewis
    "137", #Lincoln
    "147", #McCreary
    "151", #Madison
    "153", #Magoffin
    "159", #Martin
    "165", #Menifee
    "169", #Metcalfe
    "171", #Monroe
    "173", #Montgomery
    "175", #Morgan
    "181", #Nicholas
    "189", #Owsley
    "193", #Perry
    "195", #Pike
    "197", #Powell
    "199", #Pulaski
    "201", #Robertson
    "203", #Rockcastle
    "205", #Rowan
    "207", #Russell
    "231", #Wayne
    "235", #Whitley
    "237", #Wolfe
]

# %%
#Kentucky Query
KY_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": KY_state_code},
)

# %%
#Maryland Appalachia Counties
MD_state_code = "24"
MD_app_counties = [
    "1", #Allegany
    "23", #Garrett
    "43", #Washington
]

# %%
#Maryland Query
MD_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": MD_state_code},
)

# %%
#Mississippi Appalachia Counties
MS_state_code = "28"
MS_app_counties = [
    "3", #Alcorn
    "9", #Benton
    "13", #Calhoun
    "17", #Chickasaw
    "19", #Choctaw
    "25", #Clay
    "57", #Itawamba
    "69", #Kemper
    "81", #Lee
    "87", #Lowndes
    "93", #Marshall
    "95", #Monroe
    "97", #Montgomery
    "103", #Noxubee
    "105", #Oktibbeha
    "107", #Panola
    "115", #Pontotoc
    "117", #Prentiss
    "139", #Tippah
    "141", #Tishomingo
    "145", #Union
    "155", #Webster
    "159", #Winston
    "161", #Yalobusha
]

# %%
#Mississippi Query
MS_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": MS_state_code},
)

# %%
#New York Appalachia Counties
NY_state_code = "36"
NY_app_counties = [
    "3", #Allegany
    "7", #Broome
    "9", #Cattaraugus
    "13", #Chautauqua
    "15", #Chemung
    "17", #Chenango
    "23", #Cortland
    "25", #Delaware
    "77", #Otsego
    "95", #Schoharie
    "97", #Schuyler
    "101", #Steuben
    "107", #Tioga
    "109", #Tompkins
]

# %%
#New York Query
NY_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": NY_state_code},
)

# %%
#North Carolina Appalachia Counties
NC_state_code = "37"
NC_app_counties = [
    "3", #Alexander
    "5", #Alleghany
    "9", #Ashe
    "11", #Avery
    "21", #Buncombe
    "23", #Burke
    "27", #Caldwell
    "35", #Catawba
    "39", #Cherokee
    "43", #Clay
    "45", #Cleveland
    "59", #Davie
    "67", #Forsyth
    "75", #Graham
    "87", #Haywood
    "89", #Henderson
    "99", #Jackson
    "111", #McDowell
    "113", #Macon
    "115", #Madison
    "121", #Mitchell
    "149", #Polk
    "161", #Rutherford
    "169", #Stokes
    "171", #Surry
    "173", #Swain
    "175", #Transylvania
    "189", #Watauga
    "193", #Wilkes
    "197", #Yadkin
    "199", #Yancey
]

# %%
#North Carolina Query
NC_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": NC_state_code},
)

# %%
#Ohio Appalachia Counties
OH_state_code = "39"
OH_app_counties = [
    "1", #Adams
    "7", #Ashtabula
    "9", #Athens
    "13", #Belmont
    "15", #Brown
    "19", #Carroll
    "25", #Clermont
    "29", #Columbiana
    "31", #Coshocton
    "53", #Gallia
    "59", #Guernsey
    "67", #Harrison
    "71", #Highland
    "73", #Hocking
    "75", #Holmes
    "79", #Jackson
    "81", #Jefferson
    "87", #Lawrence
    "99", #Mahoning
    "105", #Meigs
    "111", #Monroe
    "115", #Morgan
    "119", #Muskingum
    "121", #Noble
    "127", #Perry
    "131", #Pike
    "141", #Ross
    "145", #Scioto
    "155", #Trumbull
    "157", #Tuscarawas
    "163", #Vinton
    "167", #Washington
]

# %%
#Ohio Query
OH_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": OH_state_code},
)

# %%
#Pennsylvania Appalachia Counties
PA_state_code = "42"
PA_app_counties = [
    "3", #Allegheny
    "5", #Armstrong
    "7", #Beaver
    "9", #Bedford
    "13", #Blair
    "15", #Bradford
    "19", #Butler
    "21", #Cambria
    "23", #Cameron
    "25", #Carbon
    "27", #Centre
    "31", #Clarion
    "33", #Clearfield
    "35", #Clinton
    "37", #Columbia
    "39", #Crawford
    "47", #Elk
    "49", #Erie
    "51", #Fayette
    "53", #Forest
    "57", #Fulton
    "59", #Greene
    "61", #Huntingdon
    "63", #Indiana
    "65", #Jefferson
    "67", #Juniata
    "69", #Lackawanna
    "73", #Lawrence
    "79", #Luzerne
    "81", #Lycoming
    "83", #McKean
    "85", #Mercer
    "87", #Mifflin
    "89", #Monroe
    "93", #Montour
    "97", #Northumberland
    "99", #Perry
    "103", #Pike
    "105", #Potter
    "107", #Schuylkill
    "109", #Snyder
    "111", #Somerset
    "113", #Sullivan
    "115", #Susquehanna
    "117", #Tioga
    "119", #Union
    "121", #Venango
    "123", #Warren
    "125", #Washington
    "127", #Wayne
    "129", #Westmoreland
    "131", #Wyoming   
]

# %%
#Pennsylvania Query
PA_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": PA_state_code},
)

# %%
#South Carolina Appalachia Counties
SC_state_code = "45"
SC_app_counties = [
    "7", #Anderson
    "21", #Cherokee
    "45", #Greenville
    "73", #Oconee
    "77", #Pickens
    "83", #Spartanburg
    "87", #Union
]

# %%
#South Carolina Query
SC_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": SC_state_code},
)

# %%
#Tennessee Appalachia Counties
TN_state_code = "47"
TN_app_counties = [
    "1", #Anderson
    "7", #Bledsoe
    "9", #Blount
    "11", #Bradley
    "13", #Campbell
    "15", #Cannon
    "19", #Carter
    "25", #Claiborne
    "27", #Clay
    "29", #Cocke
    "31", #Coffee
    "35", #Cumberland
    "41", #De Kalb
    "49", #Fentress
    "51", #Franklin
    "57", #Grainger
    "59", #Greene
    "61", #Grundy
    "63", #Hamblen
    "65", #Hamilton
    "67", #Hancock
    "73", #Hawkins
    "87", #Jackson
    "89", #Jefferson
    "91", #Johnson
    "93", #Knox
    "99", #Lawrence
    "101", #Lewis
    "105", #Loudon
    "107", #McMinn
    "111", #Macon
    "115", #Marion
    "121", #Meigs
    "123", #Monroe
    "129", #Morgan
    "133", #Overton
    "137", #Pickett
    "139", #Polk
    "141", #Putnam
    "143", #Rhea
    "145", #Roane
    "151", #Scott
    "153", #Sequatchie
    "155", #Sevier
    "159", #Smith
    "163", #Sullivan
    "171", #Unicoi
    "173", #Union
    "175", #Van Buren
    "177", #Warren
    "179", #Washington
    "185", #White
]

# %%
#Tennessee Query
TN_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": TN_state_code},
)

# %%
#Virginia Appalachia Counties
VA_state_code = "51"
VA_app_counties = [
    "005", #Alleghany
    "017", #Bath
    "021", #Bland
    "023", #Botetourt
    "027", #Buchanan
    "035", #Carroll
    "045", #Craig
    "051", #Dickenson
    "063", #Floyd
    "071", #Giles
    "077", #Grayson
    "089", #Henry
    "091", #Highland
    "105", #Lee
    "121", #Montgomery
    "141", #Patrick
    "155", #Pulaski
    "163", #Rockbridge
    "167", #Russell
    "169", #Scott
    "173", #Smyth
    "185", #Tazewell
    "191", #Washington
    "195", #Wise
    "197", #Wythe
    "520", #Bristol City (Washington County)
    "530", #Buena Vista City (Rockbridge County)
    "580", #Covington City (Alleghany County)
    "640", #Galax City (Carroll County)
    "678", #Lexington City (Rockbridge County)
    "690", #Martinsville City (Henry County)
    "720", #Norton City (Wise County)
    "750", #Radford City (Montgomery County)
]

# %%
#Virginia Query
VA_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": VA_state_code},
)

# %%
#All 55 West Virginia counties are part of Appalachia
WV_state_code = "54"

# %%
#West Virginia Query
WV_internet = acs.query(
    cols=variables,
    geo_unit="tract:*",
    geo_filter={"state": WV_state_code},
)

# %%
#Trim to Appalachian Counties
AL_app_internet = AL_internet[AL_internet.COUNTY.isin(AL_app_counties)]
GA_app_internet = GA_internet[GA_internet.COUNTY.isin(GA_app_counties)]
KY_app_internet = KY_internet[KY_internet.COUNTY.isin(KY_app_counties)]
MD_app_internet = MD_internet[MD_internet.COUNTY.isin(MD_app_counties)]
MS_app_internet = MS_internet[MS_internet.COUNTY.isin(MS_app_counties)]
NY_app_internet = NY_internet[NY_internet.COUNTY.isin(NY_app_counties)]
NC_app_internet = NC_internet[NC_internet.COUNTY.isin(NC_app_counties)]
OH_app_internet = OH_internet[OH_internet.COUNTY.isin(OH_app_counties)]
PA_app_internet = PA_internet[PA_internet.COUNTY.isin(PA_app_counties)]
SC_app_internet = SC_internet[SC_internet.COUNTY.isin(SC_app_counties)]
TN_app_internet = TN_internet[TN_internet.COUNTY.isin(TN_app_counties)]
VA_app_internet = VA_internet[VA_internet.COUNTY.isin(VA_app_counties)]

# %%
#Concat into one dataframe
app_internet = pd.concat([AL_app_internet, 
                          GA_app_internet, 
                          KY_app_internet, 
                          MD_app_internet, 
                          MS_app_internet, 
                          NY_app_internet, 
                          NC_app_internet, 
                          OH_app_internet, 
                          PA_app_internet, 
                          SC_app_internet, 
                          TN_app_internet, 
                          VA_app_internet, 
                          WV_internet
                         ])

# %%
#Convert all variables EXCEPT for NAME, State, County, and Tract into numbers
variables = variables[4:]
for variable in variables:
    if variable != "NAME":
        app_internet[variable] = app_internet[variable].astype(float)

# %%
app_internet.rename({
    "B01003_001E": "total pop",
    "B28002_001E": "Total Households for internet",
    "B28002_002E": "Total with Internet",
    "B28003_001E": "Total Households for computer",
    "B28004_001E": "Total Households for income and internet",
    "B28004_002E": "<10k",
    "B28004_006E": "10k to 20k",
    "B28004_010E": "20k to 35k",
    "B28004_014E": "35k to 50k",
    "B28004_018E": "50k to 75k",
    "B28004_022E": ">75k",
    "B28005_001E": "Total Households for age groups",
    "B28005_002E": "Under 18",
    "B28005_008E": "18 to 64",
    "B28005_014E": "65+",
    "B28006_001E": "Total Households for education",
    "B28006_002E": "Less than HS grad",
    "B28006_008E": "HS grad but not college",
    "B28006_014E": "Bachelor's or higher",
    "B28007_001E": "Total Housholds for labor force",
    "B28007_002E": "Civilian labor force",
    "B28007_003E": "Civilian labor force, employed",
    "B28007_009E": "Civilian labor force, unemployed",
    "B28007_015E": "Not in labor force"},
                axis=1, inplace=True)

# %%
#Type of Internet
app_internet["pct with internet"] = (100 * app_internet["Total with Internet"] /
                       app_internet["Total Households for internet"])
app_internet["pct with dial-up"] = (100 * app_internet["B28002_003E"] /
                       app_internet["Total Households for internet"])
app_internet["pct with broadband"] = (100 * app_internet["B28002_004E"] /
                       app_internet["Total Households for internet"])
app_internet["pct with cellular"] = (100 * app_internet["B28002_006E"] /
                       app_internet["Total Households for internet"])
app_internet["pct with BB:cable, fiber optic, or DSL"] = (100 * app_internet["B28002_008E"] /
                       app_internet["Total Households for internet"])
app_internet["pct with satelitte"] = (100 * app_internet["B28002_010E"] /
                       app_internet["Total Households for internet"])
app_internet["pct with other"] = (100 * app_internet["B28002_011E"] /
                       app_internet["Total Households for internet"])
app_internet["pct without internet"] = (100 * app_internet["B28002_013E"] /
                       app_internet["Total Households for internet"])

#Computer at Home
app_internet["pct with computer"] = (100 * app_internet["B28003_002E"] /
                       app_internet["Total Households for computer"])
app_internet["pct with comp + dial-up"] = (100 * app_internet["B28003_003E"] /
                       app_internet["Total Households for computer"])
app_internet["pct with comp + broadband"] = (100 * app_internet["B28003_004E"] /
                       app_internet["Total Households for computer"])
app_internet["pct with comp no internet"] = (100 * app_internet["B28003_005E"] /
                       app_internet["Total Households for computer"])
app_internet["pct without a computer"] = (100 * app_internet["B28003_006E"] /
                       app_internet["Total Households for computer"])

#Income and Internet
app_internet["pct <10k"] = (100 * app_internet["<10k"] /
                       app_internet["Total Households for income and internet"])
app_internet["pct <10k with dial-up"] = (100 * app_internet["B28004_003E"] /
                       app_internet["<10k"])
app_internet["pct <10k with broadband"] = (100 * app_internet["B28004_004E"] /
                       app_internet["<10k"])
app_internet["pct <10k without internet sub"] = (100 * app_internet["B28004_005E"] /
                       app_internet["<10k"])

app_internet["pct 10k-20k"] = (100 * app_internet["10k to 20k"] /
                       app_internet["Total Households for income and internet"])
app_internet["pct 10k-20k with dial-up"] = (100 * app_internet["B28004_007E"] /
                       app_internet["10k to 20k"])
app_internet["pct 10k-20k with broadband"] = (100 * app_internet["B28004_008E"] /
                       app_internet["10k to 20k"])
app_internet["pct 10k-20k without internet sub"] = (100 * app_internet["B28004_009E"] /
                       app_internet["10k to 20k"])

app_internet["pct 20k-35k"] = (100 * app_internet["20k to 35k"] /
                       app_internet["Total Households for income and internet"])
app_internet["pct 20k-35k with dial-up"] = (100 * app_internet["B28004_011E"] /
                       app_internet["20k to 35k"])
app_internet["pct 20k-35k with broadband"] = (100 * app_internet["B28004_012E"] /
                       app_internet["20k to 35k"])
app_internet["pct 20k-35k without internet sub"] = (100 * app_internet["B28004_013E"] /
                       app_internet["20k to 35k"])

app_internet["pct 35k-50k"] = (100 * app_internet["35k to 50k"] /
                       app_internet["Total Households for income and internet"])
app_internet["pct 35k-50k with dial-up"] = (100 * app_internet["B28004_015E"] /
                       app_internet["35k to 50k"])
app_internet["pct 35k-50k with broadband"] = (100 * app_internet["B28004_016E"] /
                       app_internet["35k to 50k"])
app_internet["pct 35k-50k without internet sub"] = (100 * app_internet["B28004_017E"] /
                       app_internet["35k to 50k"])

app_internet["pct 50k-75k"] = (100 * app_internet["50k to 75k"] /
                       app_internet["Total Households for income and internet"])
app_internet["pct 50k-75k with dial-up"] = (100 * app_internet["B28004_019E"] /
                       app_internet["50k to 75k"])
app_internet["pct 50k-75k with broadband"] = (100 * app_internet["B28004_020E"] /
                       app_internet["50k to 75k"])
app_internet["pct 50k-75k without internet sub"] = (100 * app_internet["B28004_021E"] /
                       app_internet["50k to 75k"])

app_internet["pct >75k"] = (100 * app_internet[">75k"] /
                       app_internet["Total Households for income and internet"])
app_internet["pct >75k with dial-up"] = (100 * app_internet["B28004_023E"] /
                       app_internet[">75k"])
app_internet["pct >75k with broadband"] = (100 * app_internet["B28004_024E"] /
                       app_internet[">75k"])
app_internet["pct >75k without internet sub"] = (100 * app_internet["B28004_025E"] /
                       app_internet[">75k"])

#Age and Internet
app_internet["pct under 18"] = (100 * app_internet["Under 18"] /
                       app_internet["Total Households for age groups"])
app_internet["pct under 18, has a computer"] = (100 * app_internet["B28005_003E"] /
                       app_internet["Under 18"])
app_internet["pct under 18, has a comp + dial-up"] = (100 * app_internet["B28005_004E"] /
                       app_internet["Under 18"])
app_internet["pct under 18, has a comp + broadband"] = (100 * app_internet["B28005_005E"] /
                       app_internet["Under 18"])
app_internet["pct under 18, has a comp, no internet"] = (100 * app_internet["B28005_006E"] /
                       app_internet["Under 18"])
app_internet["pct under 18, no comp"] = (100 * app_internet["B28005_007E"] /
                       app_internet["Under 18"])

app_internet["pct 18-64"] = (100 * app_internet["18 to 64"] /
                       app_internet["Total Households for age groups"])
app_internet["pct 18-64, has a computer"] = (100 * app_internet["B28005_009E"] /
                       app_internet["18 to 64"])
app_internet["pct 18-64, has a comp + dial-up"] = (100 * app_internet["B28005_010E"] /
                       app_internet["18 to 64"])
app_internet["pct 18-64, has a comp + broadband"] = (100 * app_internet["B28005_011E"] /
                       app_internet["18 to 64"])
app_internet["pct 18-64, has a comp, no internet"] = (100 * app_internet["B28005_012E"] /
                       app_internet["18 to 64"])
app_internet["pct 18-64, no comp"] = (100 * app_internet["B28005_013E"] /
                       app_internet["18 to 64"])

app_internet["pct 65+"] = (100 * app_internet["65+"] /
                       app_internet["Total Households for age groups"])
app_internet["pct 65+, has a computer"] = (100 * app_internet["B28005_015E"] /
                       app_internet["65+"])
app_internet["pct 65+, has a comp + dial-up"] = (100 * app_internet["B28005_016E"] /
                       app_internet["65+"])
app_internet["pct 65+, has a comp + broadband"] = (100 * app_internet["B28005_017E"] /
                       app_internet["65+"])
app_internet["pct 65+, has a comp, no internet"] = (100 * app_internet["B28005_018E"] /
                       app_internet["65+"])
app_internet["pct 65+, no comp"] = (100 * app_internet["B28005_019E"] /
                       app_internet["65+"])

#Education and Internet
app_internet["pct <HS"] = (100 * app_internet["Less than HS grad"] /
                       app_internet["Total Households for education"])
app_internet["pct <HS, has a computer"] = (100 * app_internet["B28006_003E"] /
                       app_internet["Less than HS grad"])
app_internet["pct <HS, has a comp + dial-up"] = (100 * app_internet["B28006_004E"] /
                       app_internet["Less than HS grad"])
app_internet["pct <HS, has a comp + broadband"] = (100 * app_internet["B28006_005E"] /
                       app_internet["Less than HS grad"])
app_internet["pct <HS, has a comp, no internet"] = (100 * app_internet["B28006_006E"] /
                       app_internet["Less than HS grad"])
app_internet["pct <HS, no comp"] = (100 * app_internet["B28006_007E"] /
                       app_internet["Less than HS grad"])

app_internet["pct HS grad"] = (100 * app_internet["HS grad but not college"] /
                       app_internet["Total Households for education"])
app_internet["pct HS grad, has a computer"] = (100 * app_internet["B28006_009E"] /
                       app_internet["HS grad but not college"])
app_internet["pct HS grad, has a comp + dial-up"] = (100 * app_internet["B28006_010E"] /
                       app_internet["HS grad but not college"])
app_internet["pct HS grad, has a comp + broadband"] = (100 * app_internet["B28006_011E"] /
                       app_internet["HS grad but not college"])
app_internet["pct HS grad, has a comp, no internet"] = (100 * app_internet["B28006_012E"] /
                       app_internet["HS grad but not college"])
app_internet["pct HS grad, no comp"] = (100 * app_internet["B28006_013E"] /
                       app_internet["HS grad but not college"])

app_internet["pct Bach+"] = (100 * app_internet["Bachelor's or higher"] /
                       app_internet["Total Households for education"])
app_internet["pct Bach+, has a computer"] = (100 * app_internet["B28006_015E"] /
                       app_internet["Bachelor's or higher"])
app_internet["pct Bach+, has a comp + dial-up"] = (100 * app_internet["B28006_016E"] /
                       app_internet["Bachelor's or higher"])
app_internet["pct Bach+, has a comp + broadband"] = (100 * app_internet["B28006_017E"] /
                       app_internet["Bachelor's or higher"])
app_internet["pct Bach+, has a comp, no internet"] = (100 * app_internet["B28006_018E"] /
                       app_internet["Bachelor's or higher"])
app_internet["pct Bach+, no comp"] = (100 * app_internet["B28006_019E"] /
                       app_internet["Bachelor's or higher"])


#Work force and Internet
app_internet["pct civilian-employed"] = (100 * app_internet["Civilian labor force, employed"] /
                       app_internet["Total Housholds for labor force"])
app_internet["pct civilian-employed, has a computer"] = (100 * app_internet["B28007_004E"] /
                       app_internet["Civilian labor force, employed"])
app_internet["pct civilian-employed, has a comp + dial-up"] = (100 * app_internet["B28007_005E"] /
                       app_internet["Civilian labor force, employed"])
app_internet["pct civilian-employed, has a comp + broadband"] = (100 * app_internet["B28007_006E"] /
                       app_internet["Civilian labor force, employed"])
app_internet["pct civilian-employed, has a comp, no internet"] = (100 * app_internet["B28007_007E"] /
                       app_internet["Civilian labor force, employed"])
app_internet["pct , no comp"] = (100 * app_internet["B28007_008E"] /
                       app_internet["Civilian labor force, employed"])

app_internet["pct civilian-unemployed"] = (100 * app_internet["Civilian labor force, unemployed"] /
                       app_internet["Total Housholds for labor force"])
app_internet["pct civilian-unemployed, has a computer"] = (100 * app_internet["B28007_010E"] /
                       app_internet["Civilian labor force, unemployed"])
app_internet["pct civilian-unemployed, has a comp + dial-up"] = (100 * app_internet["B28007_011E"] /
                       app_internet["Civilian labor force, unemployed"])
app_internet["pct civilian-unemployed, has a comp + broadband"] = (100 * app_internet["B28007_012E"] /
                       app_internet["Civilian labor force, unemployed"])
app_internet["pct civilian-unemployed, has a comp, no internet"] = (100 * app_internet["B28007_013E"] /
                       app_internet["Civilian labor force, unemployed"])
app_internet["pct civilian-unemployed, no comp"] = (100 * app_internet["B28007_014E"] /
                       app_internet["Civilian labor force, unemployed"])

app_internet["pct not in labor force"] = (100 * app_internet["Not in labor force"] /
                       app_internet["Total Housholds for labor force"])
app_internet["pct not in labor force, has a computer"] = (100 * app_internet["B28007_016E"] /
                       app_internet["Not in labor force"])
app_internet["pct not in labor force, has a comp + dial-up"] = (100 * app_internet["B28007_017E"] /
                       app_internet["Not in labor force"])
app_internet["pct not in labor force, has a comp + broadband"] = (100 * app_internet["B28007_018E"] /
                       app_internet["Not in labor force"])
app_internet["pct not in labor force, has a comp, no internet"] = (100 * app_internet["B28007_019E"] /
                       app_internet["Not in labor force"])
app_internet["pct not in labor force, no comp"] = (100 * app_internet["B28007_020E"] /
                       app_internet["Not in labor force"])
# Out:
# /var/folders/r8/dg1zrwcd6gbgcrc59pn6x1yc0000gn/T/ipykernel_96093/2667259457.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   app_internet["pct with internet"] = (100 * app_internet["Total with Internet"] /
# /var/folders/r8/dg1zrwcd6gbgcrc59pn6x1yc0000gn/T/ipykernel_96093/2667259457.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   app_internet["pct with dial-up"] = (100 * app_internet["B28002_003E"] /
# ...

# %%
app_internet = app_internet[app_internet.columns.drop(list(app_internet.filter(regex='B2800')))]

# %%
AL_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_01_tract")
GA_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_13_tract")
KY_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_21_tract")
MD_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_24_tract")
MS_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_28_tract")
NY_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_36_tract")
NC_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_37_tract")
OH_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_39_tract")
PA_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_42_tract")
SC_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_45_tract")
TN_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_47_tract")
VA_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_51_tract")
WV_shape = gpd.read_file("/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/Tract Shapes/tl_2020_54_tract")

# %%
App_tract_geo = pd.concat([AL_shape,
                          GA_shape,
                          KY_shape,
                          MD_shape,
                          MS_shape,
                          NY_shape,
                          NC_shape,
                          OH_shape,
                          PA_shape,
                          SC_shape,
                          TN_shape,
                          VA_shape,
                          WV_shape
                          ])

# %%
App_tract = pd.merge(app_internet, App_tract_geo, how='left', left_on=['STATE', 'COUNTY', 'TRACT'], right_on=['STATEFP', 'COUNTYFP', 'TRACTCE'])

# %%
App_tract["pop_density"] = (App_tract["total pop"] /
                       (App_tract["ALAND"] + App_tract["AWATER"]))
App_tract["pop_density_land"] = (App_tract["total pop"] /
                       (App_tract["ALAND"]))

# %%
App_tract = App_tract[App_tract.columns.drop(["state", "county", "tract", "STATEFP", "COUNTYFP", "TRACTCE", "NAME_y", "NAMELSAD", "MTFCC", "FUNCSTAT", "INTPTLAT", "INTPTLON"])]

# %%
reorder = [
        'NAME_x',
        'STATE',
        'COUNTY',
        'TRACT',
        'GEOID',
        'pop_density',
        'pop_density_land',
        'total pop',
        'Total Households for internet',
        'Total with Internet',
        'Total Households for computer',
        'Total Households for income and internet',
        '<10k',
        '10k to 20k',
        '20k to 35k',
        '35k to 50k',
        '50k to 75k',
        '>75k',
        'Total Households for age groups',
        'Under 18',
        '18 to 64',
        '65+',
        'Total Households for education',
        'Less than HS grad',
        'HS grad but not college',
        "Bachelor's or higher",
        'Total Housholds for labor force',
        'Civilian labor force',
        'Civilian labor force, employed',
        'Civilian labor force, unemployed',
        'Not in labor force',
        'pct with internet',
        'pct with dial-up',
        'pct with broadband',
        'pct with cellular',
        'pct with BB:cable, fiber optic, or DSL',
        'pct with satelitte',
        'pct with other',
        'pct without internet',
        'pct with computer',
        'pct with comp + dial-up',
        'pct with comp + broadband',
        'pct with comp no internet',
        'pct without a computer',
        'pct <10k',
        'pct <10k with dial-up',
        'pct <10k with broadband',
        'pct <10k without internet sub',
        'pct 10k-20k',
        'pct 10k-20k with dial-up',
        'pct 10k-20k with broadband',
        'pct 10k-20k without internet sub',
        'pct 20k-35k',
        'pct 20k-35k with dial-up',
        'pct 20k-35k with broadband',
        'pct 20k-35k without internet sub',
        'pct 35k-50k',
        'pct 35k-50k with dial-up',
        'pct 35k-50k with broadband',
        'pct 35k-50k without internet sub',
        'pct 50k-75k',
        'pct 50k-75k with dial-up',
        'pct 50k-75k with broadband',
        'pct 50k-75k without internet sub',
        'pct >75k',
        'pct >75k with dial-up',
        'pct >75k with broadband',
        'pct >75k without internet sub',
        'pct under 18',
        'pct under 18, has a computer',
        'pct under 18, has a comp + dial-up',
        'pct under 18, has a comp + broadband',
        'pct under 18, has a comp, no internet',
        'pct under 18, no comp',
        'pct 18-64',
        'pct 18-64, has a computer',
        'pct 18-64, has a comp + dial-up',
        'pct 18-64, has a comp + broadband',
        'pct 18-64, has a comp, no internet',
        'pct 18-64, no comp',
        'pct 65+',
        'pct 65+, has a computer',
        'pct 65+, has a comp + dial-up',
        'pct 65+, has a comp + broadband',
        'pct 65+, has a comp, no internet',
        'pct 65+, no comp',
        'pct <HS',
        'pct <HS, has a computer',
        'pct <HS, has a comp + dial-up',
        'pct <HS, has a comp + broadband',
        'pct <HS, has a comp, no internet',
        'pct <HS, no comp',
        'pct HS grad',
        'pct HS grad, has a computer',
        'pct HS grad, has a comp + dial-up',
        'pct HS grad, has a comp + broadband',
        'pct HS grad, has a comp, no internet',
        'pct HS grad, no comp',
        'pct Bach+',
        'pct Bach+, has a computer',
        'pct Bach+, has a comp + dial-up',
        'pct Bach+, has a comp + broadband',
        'pct Bach+, has a comp, no internet',
        'pct Bach+, no comp',
        'pct civilian-employed',
        'pct civilian-employed, has a computer',
        'pct civilian-employed, has a comp + dial-up',
        'pct civilian-employed, has a comp + broadband',
        'pct civilian-employed, has a comp, no internet',
        'pct , no comp',
        'pct civilian-unemployed',
        'pct civilian-unemployed, has a computer',
        'pct civilian-unemployed, has a comp + dial-up',
        'pct civilian-unemployed, has a comp + broadband',
        'pct civilian-unemployed, has a comp, no internet',
        'pct civilian-unemployed, no comp',
        'pct not in labor force',
        'pct not in labor force, has a computer',
        'pct not in labor force, has a comp + dial-up',
        'pct not in labor force, has a comp + broadband',
        'pct not in labor force, has a comp, no internet',
        'pct not in labor force, no comp',
        'ALAND',
        'AWATER',
        'geometry',
]
App_tract = App_tract[reorder]

# %%
App_tract = gpd.GeoDataFrame(App_tract)
App_tract.to_file('/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/App_Tract/App_Tract.shp')
# Out:
# /var/folders/r8/dg1zrwcd6gbgcrc59pn6x1yc0000gn/T/ipykernel_96093/1744890403.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   App_tract.to_file('/Users/baiken/Documents/GitHub/680/Aiken_Ben_AppalachiaBroadband/raw_data/App_Tract/App_Tract.shp')
